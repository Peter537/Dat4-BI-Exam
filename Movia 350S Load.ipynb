# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

import xml.etree.ElementTree as ET

# %%
# Load the XML file
tree = ET.parse('NX-PI-01_DK_NAP_LINE_MOVIA-MOVIA-350S_20240212.xml')

# %%
# Define the namespace map
namespace = {'netex': 'http://www.netex.org.uk/netex'}

root = tree.getroot()
print("Root", root.tag)
# Out:
# Root {http://www.netex.org.uk/netex}PublicationDelivery

# %%
publication_timestamp_element = root.find(".//netex:PublicationTimestamp", namespace)
print("Publication timestamp", publication_timestamp_element.text)

network_filter_element = root.find(".//netex:NetworkFilterByValue", namespace)
print("Network filter", network_filter_element.find(".//netex:LineRef", namespace).attrib['ref'])
# Out:
# Publication timestamp 2024-02-12T12:01:18
# Network filter DK::Line:7387::

# %%
# GET THE ROUTE POINTS

dataObjects = root.find(".//netex:dataObjects", namespace)
print("Data objects", dataObjects.tag)

routePoints = dataObjects.find(".//netex:routePoints", namespace)
print("Route points", routePoints.tag)

for routePoint in routePoints.findall(".//netex:RoutePoint", namespace):
    print(routePoint.attrib['id'])
    location = routePoint.find(".//netex:Location", namespace)
    print(location.find(".//netex:Longitude", namespace).text)
    print(location.find(".//netex:Latitude", namespace).text)
    print()
# Out:
# Data objects {http://www.netex.org.uk/netex}dataObjects
# Route points {http://www.netex.org.uk/netex}routePoints
# DK::RoutePoint:56408540_1::
# 12.3583067060238
# 55.7301773683848
#
# DK::RoutePoint:56445333_1::
# 12.3578150960425
# 55.7235284922789
#
# DK::RoutePoint:56445332_1::
# 12.363257140873
# 55.723271567544
#
# DK::RoutePoint:56445331_1::
# 12.3772357741199
# 55.722069459547
#
# DK::RoutePoint:56445808_1::
# 12.3855624921131
# 55.7242226451787
#
# DK::RoutePoint:56445329_1::
# 12.3884876010804
# 55.7316854396853
#
# DK::RoutePoint:56445327_1::
# 12.3970140486088
# 55.7300560980455
#
# DK::RoutePoint:56445325_1::
# 12.4099375450394
# 55.7260562573844
#
# DK::RoutePoint:56445324_1::
# 12.421585212238
# 55.7253454159427
#
# DK::RoutePoint:56445323_1::
# 12.4292599551389
# 55.7249333703212
#
# DK::RoutePoint:56445322_1::
# 12.4390443083857
# 55.7229691835088
#
# DK::RoutePoint:56447345_1::
# 12.4496638798732
# 55.7198298331992
#
# DK::RoutePoint:56434463_1::
# 12.4623226339693
# 55.7150944849763
#
# DK::RoutePoint:56445350_1::
# 12.4722359487392
# 55.7119370796719
#
# DK::RoutePoint:56445349_1::
# 12.4781721279055
# 55.7102763512927
#
# DK::RoutePoint:56445348_1::
# 12.4879071518369
# 55.7067540437029
#
# DK::RoutePoint:56445346_1::
# 12.498931237747
# 55.7044889489058
#
# DK::RoutePoint:56445344_1::
# 12.5171341694521
# 55.7066388784524
#
# DK::RoutePoint:56445342_1::
# 12.5225795078562
# 55.705745322079
#
# DK::RoutePoint:56434274_1::
# 12.5389583890724
# 55.7005622629528
#
# DK::RoutePoint:56445340_1::
# 12.5494828009122
# 55.6938920427189
#
# DK::RoutePoint:56445339_1::
# 12.5589121244
# 55.6885204771682
#
# DK::RoutePoint:56438306_1::
# 12.572622677735
# 55.6840485502942
#
# DK::RoutePoint:56445287_1::
# 12.5720343688669
# 55.6837060173724
#
# DK::RoutePoint:56445286_1::
# 12.5674674362558
# 55.6852866372326
#
# DK::RoutePoint:56438149_1::
# 12.5575908516874
# 55.6890443665295
#
# DK::RoutePoint:56438146_1::
# 12.5492584626534
# 55.6940513937787
#
# DK::RoutePoint:56435518_1::
# 12.5375268954509
# 55.7011070881587
#
# DK::RoutePoint:56435516_1::
# 12.5204390350146
# 55.7062023989465
#
# DK::RoutePoint:56435515_1::
# 12.5163900595727
# 55.7066871854935
#
# DK::RoutePoint:56435513_1::
# 12.4983190190583
# 55.7045873334467
#
# DK::RoutePoint:56438060_1::
# 12.4862587142633
# 55.7073763548674
#
# DK::RoutePoint:56438057_1::
# 12.4761556138586
# 55.7108819823278
#
# DK::RoutePoint:56448369_1::
# 12.4716291155719
# 55.7120981153749
#
# DK::RoutePoint:56435283_1::
# 12.4605232790704
# 55.7158196016203
#
# DK::RoutePoint:56448049_1::
# 12.4482780097349
# 55.7205521285478
#
# DK::RoutePoint:56448045_1::
# 12.4429514227142
# 55.7224729913637
#
# DK::RoutePoint:56448041_1::
# 12.4274758991245
# 55.7251180833916
#
# DK::RoutePoint:56434629_1::
# 12.4205337391126
# 55.7255275805806
#
# DK::RoutePoint:56434628_1::
# 12.4087739587936
# 55.7262324442
#
# DK::RoutePoint:56434627_1::
# 12.3966770054221
# 55.7305779213016
#
# DK::RoutePoint:56440123_1::
# 12.3881002190096
# 55.731444384278
#
# DK::RoutePoint:56440121_1::
# 12.3858506839706
# 55.7251587585153
#
# DK::RoutePoint:56440120_1::
# 12.3760601272248
# 55.7222906227272
#
# DK::RoutePoint:56438391_1::
# 12.3649266654114
# 55.7232347893671
#
# DK::RoutePoint:56445810_1::
# 12.3560840759821
# 55.7239624588614

# %%
# LINK ROUTES TO ROUTE POINTS

routes = dataObjects.find(".//netex:routes", namespace)
print("Routes", routes.tag)

for route in routes.findall(".//netex:Route", namespace):
    print(route.attrib['id'])
    print(route.find(".//netex:LineRef", namespace).attrib['ref'])
    print(route.find(".//netex:DirectionRef", namespace).attrib['ref'])
    pointsInSequence = route.find(".//netex:pointsInSequence", namespace)
    for pointInSequence in pointsInSequence.findall(".//netex:PointOnRoute", namespace):
        print("RoutePoint", pointInSequence.attrib['id'])
        print("RoutePointRef", pointInSequence.find(".//netex:RoutePointRef", namespace).attrib['ref'])
    print()
# Out:
# Routes {http://www.netex.org.uk/netex}routes
# DK::Route:12037496_1::
# DK::Line:7387::
# DK::Direction:1::
# RoutePoint DK::PointOnRoute:12037496_1_0::
# RoutePointRef DK::RoutePoint:56408540_1::
# RoutePoint DK::PointOnRoute:12037496_1_1::
# RoutePointRef DK::RoutePoint:56445333_1::
# RoutePoint DK::PointOnRoute:12037496_1_2::
# RoutePointRef DK::RoutePoint:56445332_1::
# RoutePoint DK::PointOnRoute:12037496_1_3::
# RoutePointRef DK::RoutePoint:56445331_1::
# RoutePoint DK::PointOnRoute:12037496_1_4::
# RoutePointRef DK::RoutePoint:56445808_1::
# RoutePoint DK::PointOnRoute:12037496_1_5::
# RoutePointRef DK::RoutePoint:56445329_1::
# RoutePoint DK::PointOnRoute:12037496_1_6::
# RoutePointRef DK::RoutePoint:56445327_1::
# RoutePoint DK::PointOnRoute:12037496_1_7::
# RoutePointRef DK::RoutePoint:56445325_1::
# RoutePoint DK::PointOnRoute:12037496_1_8::
# RoutePointRef DK::RoutePoint:56445324_1::
# RoutePoint DK::PointOnRoute:12037496_1_9::
# RoutePointRef DK::RoutePoint:56445323_1::
# RoutePoint DK::PointOnRoute:12037496_1_10::
# RoutePointRef DK::RoutePoint:56445322_1::
# RoutePoint DK::PointOnRoute:12037496_1_11::
# RoutePointRef DK::RoutePoint:56447345_1::
# RoutePoint DK::PointOnRoute:12037496_1_12::
# RoutePointRef DK::RoutePoint:56434463_1::
# RoutePoint DK::PointOnRoute:12037496_1_13::
# RoutePointRef DK::RoutePoint:56445350_1::
# RoutePoint DK::PointOnRoute:12037496_1_14::
# RoutePointRef DK::RoutePoint:56445349_1::
# RoutePoint DK::PointOnRoute:12037496_1_15::
# RoutePointRef DK::RoutePoint:56445348_1::
# RoutePoint DK::PointOnRoute:12037496_1_16::
# RoutePointRef DK::RoutePoint:56445346_1::
# RoutePoint DK::PointOnRoute:12037496_1_17::
# RoutePointRef DK::RoutePoint:56445344_1::
# RoutePoint DK::PointOnRoute:12037496_1_18::
# RoutePointRef DK::RoutePoint:56445342_1::
# RoutePoint DK::PointOnRoute:12037496_1_19::
# RoutePointRef DK::RoutePoint:56434274_1::
# RoutePoint DK::PointOnRoute:12037496_1_20::
# RoutePointRef DK::RoutePoint:56445340_1::
# RoutePoint DK::PointOnRoute:12037496_1_21::
# RoutePointRef DK::RoutePoint:56445339_1::
# RoutePoint DK::PointOnRoute:12037496_1_22::
# RoutePointRef DK::RoutePoint:56438306_1::
#
# DK::Route:12037497_1::
# DK::Line:7387::
# DK::Direction:2::
# RoutePoint DK::PointOnRoute:12037497_1_0::
# RoutePointRef DK::RoutePoint:56445287_1::
# RoutePoint DK::PointOnRoute:12037497_1_1::
# RoutePointRef DK::RoutePoint:56445286_1::
# RoutePoint DK::PointOnRoute:12037497_1_2::
# RoutePointRef DK::RoutePoint:56438149_1::
# RoutePoint DK::PointOnRoute:12037497_1_3::
# RoutePointRef DK::RoutePoint:56438146_1::
# RoutePoint DK::PointOnRoute:12037497_1_4::
# RoutePointRef DK::RoutePoint:56435518_1::
# RoutePoint DK::PointOnRoute:12037497_1_5::
# RoutePointRef DK::RoutePoint:56435516_1::
# RoutePoint DK::PointOnRoute:12037497_1_6::
# RoutePointRef DK::RoutePoint:56435515_1::
# RoutePoint DK::PointOnRoute:12037497_1_7::
# RoutePointRef DK::RoutePoint:56435513_1::
# RoutePoint DK::PointOnRoute:12037497_1_8::
# RoutePointRef DK::RoutePoint:56438060_1::
# RoutePoint DK::PointOnRoute:12037497_1_9::
# RoutePointRef DK::RoutePoint:56438057_1::
# RoutePoint DK::PointOnRoute:12037497_1_10::
# RoutePointRef DK::RoutePoint:56448369_1::
# RoutePoint DK::PointOnRoute:12037497_1_11::
# RoutePointRef DK::RoutePoint:56435283_1::
# RoutePoint DK::PointOnRoute:12037497_1_12::
# RoutePointRef DK::RoutePoint:56448049_1::
# RoutePoint DK::PointOnRoute:12037497_1_13::
# RoutePointRef DK::RoutePoint:56448045_1::
# RoutePoint DK::PointOnRoute:12037497_1_14::
# RoutePointRef DK::RoutePoint:56448041_1::
# RoutePoint DK::PointOnRoute:12037497_1_15::
# RoutePointRef DK::RoutePoint:56434629_1::
# RoutePoint DK::PointOnRoute:12037497_1_16::
# RoutePointRef DK::RoutePoint:56434628_1::
# RoutePoint DK::PointOnRoute:12037497_1_17::
# RoutePointRef DK::RoutePoint:56434627_1::
# RoutePoint DK::PointOnRoute:12037497_1_18::
# RoutePointRef DK::RoutePoint:56440123_1::
# RoutePoint DK::PointOnRoute:12037497_1_19::
# RoutePointRef DK::RoutePoint:56440121_1::
# RoutePoint DK::PointOnRoute:12037497_1_20::
# RoutePointRef DK::RoutePoint:56440120_1::
# RoutePoint DK::PointOnRoute:12037497_1_21::
# RoutePointRef DK::RoutePoint:56438391_1::
# RoutePoint DK::PointOnRoute:12037497_1_22::
# RoutePointRef DK::RoutePoint:56445810_1::
# RoutePoint DK::PointOnRoute:12037497_1_23::
# RoutePointRef DK::RoutePoint:56408540_1::

# %%
# Destination displays

destinationDisplays = dataObjects.find(".//netex:destinationDisplays", namespace)
print("Destination displays", destinationDisplays.tag)

for destinationDisplay in destinationDisplays.findall(".//netex:DestinationDisplay", namespace):
    print(destinationDisplay.attrib['id'])
    print(destinationDisplay.find(".//netex:SideText", namespace).text)
    print(destinationDisplay.find(".//netex:FrontText", namespace).text)
    print()
# Out:
# Destination displays {http://www.netex.org.uk/netex}destinationDisplays
# DK::DestinationDisplay:3569::
# Nørreport St.
# Nørreport St.
#
# DK::DestinationDisplay:3570::
# Ballerup St.
# Ballerup St.

# %%
# Scheduled stop points

scheduledStopPoints = dataObjects.find(".//netex:scheduledStopPoints", namespace)
print("Scheduled stop points", scheduledStopPoints.tag)

for scheduledStopPoint in scheduledStopPoints.findall(".//netex:ScheduledStopPoint", namespace):
    print(scheduledStopPoint.attrib['id'])
    print(scheduledStopPoint.find(".//netex:Name", namespace).text)
    location = scheduledStopPoint.find(".//netex:Location", namespace)
    print(location.find(".//netex:Longitude", namespace).text)
    print(location.find(".//netex:Latitude", namespace).text)
    print()
# Out:
# Scheduled stop points {http://www.netex.org.uk/netex}scheduledStopPoints
# DK::ScheduledStopPoint:52626_Movia_B::
# Ballerup St. (Banegårdspladsen)
# 12.3583067060238
# 55.7301773683848
#
# DK::ScheduledStopPoint:4523_Movia_::
# Psykiatrisk Center Ballerup (Ballerup Boulevard)
# 12.3578150960425
# 55.7235284922789
#
# DK::ScheduledStopPoint:3528_Movia_::
# Ring 4 (Ballerup Boulevard)
# 12.363257140873
# 55.723271567544
#
# DK::ScheduledStopPoint:4414_Movia_::
# Tempovej (Ballerup Boulevard)
# 12.3772357741199
# 55.722069459547
#
# DK::ScheduledStopPoint:4415_Movia_::
# Malmparken St. (Malmparken)
# 12.3855624921131
# 55.7242226451787
#
# DK::ScheduledStopPoint:2132_Movia_::
# Ballerup, Borupvang (Lautrupparken)
# 12.3884876010804
# 55.7316854396853
#
# DK::ScheduledStopPoint:2134_Movia_::
# DTU Ballerup Campus (Lautrupvang)
# 12.3970140486088
# 55.7300560980455
#
# DK::ScheduledStopPoint:2137_Movia_::
# Torvevej (Skovlunde Byvej)
# 12.4099375450394
# 55.7260562573844
#
# DK::ScheduledStopPoint:2139_Movia_::
# Virkeholm (Herlev Hovedgade)
# 12.421585212238
# 55.7253454159427
#
# DK::ScheduledStopPoint:2140_Movia_::
# Marielundvej (Herlev Hovedgade)
# 12.4292599551389
# 55.7249333703212
#
# DK::ScheduledStopPoint:285_Movia_::
# Herlev Bymidte (Herlev Hovedgade)
# 12.4390443083857
# 55.7229691835088
#
# DK::ScheduledStopPoint:2143_Movia_::
# Elverhøjen (Herlev Hovedgade)
# 12.4496638798732
# 55.7198298331992
#
# DK::ScheduledStopPoint:2146_Movia_::
# Åfløjen (Frederikssundsvej)
# 12.4623226339693
# 55.7150944849763
#
# DK::ScheduledStopPoint:2148_Movia_::
# Husum Torv (Frederikssundsvej)
# 12.4722359487392
# 55.7119370796719
#
# DK::ScheduledStopPoint:2275_Movia_::
# Husumvej (Frederikssundsvej)
# 12.4781721279055
# 55.7102763512927
#
# DK::ScheduledStopPoint:2008_Movia_::
# Veksøvej (Frederikssundsvej)
# 12.4879071518369
# 55.7067540437029
#
# DK::ScheduledStopPoint:2010_Movia_::
# Brønshøj Torv (Frederikssundsvej)
# 12.498931237747
# 55.7044889489058
#
# DK::ScheduledStopPoint:2149_Movia_::
# Bellahøj (Frederikssundsvej)
# 12.5171500530369
# 55.7066384230479
#
# DK::ScheduledStopPoint:2150_Movia_::
# Hulgårds Plads (Frederikssundsvej)
# 12.5225795078562
# 55.705745322079
#
# DK::ScheduledStopPoint:2151_Movia_::
# Nørrebro St. (Nørrebrogade)
# 12.5389583890724
# 55.7005622629528
#
# DK::ScheduledStopPoint:2152_Movia_::
# Nørrebros Runddel St. (Nørrebrogade)
# 12.5494828009122
# 55.6938920427189
#
# DK::ScheduledStopPoint:45740_Movia_::
# Elmegade (Nørrebrogade)
# 12.5589121244
# 55.6885204771682
#
# DK::ScheduledStopPoint:6584_Movia_::
# Nørreport St. (Nørre Voldgade)
# 12.572622677735
# 55.6840485502942
#
# DK::ScheduledStopPoint:28329_Movia_::
# Nørreport St. (Nørre Voldgade)
# 12.5720343688669
# 55.6837060173724
#
# DK::ScheduledStopPoint:2157_Movia_::
# Nørre Farimagsgade (Frederiksborggade)
# 12.5674674362558
# 55.6852866372326
#
# DK::ScheduledStopPoint:45739_Movia_::
# Elmegade (Nørrebrogade)
# 12.5575908516874
# 55.6890443665295
#
# DK::ScheduledStopPoint:2159_Movia_::
# Nørrebros Runddel St. (Nørrebrogade)
# 12.5492584626534
# 55.6940513937787
#
# DK::ScheduledStopPoint:52657_Movia_::
# Nørrebro St. (Frederikssundsvej)
# 12.5375268954509
# 55.7011070881587
#
# DK::ScheduledStopPoint:2161_Movia_::
# Hulgårds Plads (Frederikssundsvej)
# 12.5204390350146
# 55.7062023989465
#
# DK::ScheduledStopPoint:2162_Movia_::
# Bellahøj (Frederikssundsvej)
# 12.5163900595727
# 55.7066871854935
#
# DK::ScheduledStopPoint:2022_Movia_::
# Brønshøj Torv (Frederikssundsvej)
# 12.4983190190583
# 55.7045873334467
#
# DK::ScheduledStopPoint:2024_Movia_::
# Veksøvej (Frederikssundsvej)
# 12.4862587142633
# 55.7073763548674
#
# DK::ScheduledStopPoint:2121_Movia_::
# Husumvej (Frederikssundsvej)
# 12.4761556138586
# 55.7108819823278
#
# DK::ScheduledStopPoint:258_Movia_::
# Husum Torv (Frederikssundsvej)
# 12.4716291155719
# 55.7120981153749
#
# DK::ScheduledStopPoint:2164_Movia_::
# Åfløjen (Frederikssundsvej)
# 12.4605232790704
# 55.7158196016203
#
# DK::ScheduledStopPoint:23_Movia_::
# Elverhøjen (Herlev Hovedgade)
# 12.4482780097349
# 55.7205521285478
#
# DK::ScheduledStopPoint:260_Movia_::
# Herlev Bymidte (Herlev Hovedgade)
# 12.4429514227142
# 55.7224729913637
#
# DK::ScheduledStopPoint:2169_Movia_::
# Marielundvej (Herlev Hovedgade)
# 12.4274758991245
# 55.7251180833916
#
# DK::ScheduledStopPoint:2170_Movia_::
# Virkeholm (Herlev Hovedgade)
# 12.4205337391126
# 55.7255275805806
#
# DK::ScheduledStopPoint:2172_Movia_::
# Torvevej (Skovlunde Byvej)
# 12.4087739587936
# 55.7262324442
#
# DK::ScheduledStopPoint:2175_Movia_::
# DTU Ballerup Campus (Lautrupvang)
# 12.3966770054221
# 55.7305779213016
#
# DK::ScheduledStopPoint:2177_Movia_::
# Ballerup, Borupvang (Lautrupparken)
# 12.3881002190096
# 55.731444384278
#
# DK::ScheduledStopPoint:4451_Movia_::
# Malmparken St. (Malmparken)
# 12.3858506839706
# 55.7251587585153
#
# DK::ScheduledStopPoint:4453_Movia_::
# Tempovej (Ballerup Boulevard)
# 12.3760601272248
# 55.7222906227272
#
# DK::ScheduledStopPoint:3560_Movia_::
# Ring 4 (Ballerup Boulevard)
# 12.3649266654114
# 55.7232347893671
#
# DK::ScheduledStopPoint:3561_Movia_::
# Psykiatrisk Center Ballerup (Hold-an Vej)
# 12.3560840759821
# 55.7239624588614

# %%
# Service links

serviceLinks = dataObjects.find(".//netex:serviceLinks", namespace)
print("Service links", serviceLinks.tag)

for serviceLink in serviceLinks.findall(".//netex:ServiceLink", namespace):
    print(serviceLink.attrib['id'])
    print(serviceLink.find(".//netex:FromPointRef", namespace).attrib['ref'])
    print(serviceLink.find(".//netex:ToPointRef", namespace).attrib['ref'])
    print()
# Out:
# Service links {http://www.netex.org.uk/netex}serviceLinks
# DK::ServiceLink:701448_B_514637_::
# DK::ScheduledStopPoint:4523_Movia_::
# DK::ScheduledStopPoint:52626_Movia_B::
#
# DK::ServiceLink:514637__513847_::
# DK::ScheduledStopPoint:3528_Movia_::
# DK::ScheduledStopPoint:4523_Movia_::
#
# DK::ServiceLink:513847__514574_::
# DK::ScheduledStopPoint:4414_Movia_::
# DK::ScheduledStopPoint:3528_Movia_::
#
# DK::ServiceLink:514574__514575_::
# DK::ScheduledStopPoint:4415_Movia_::
# DK::ScheduledStopPoint:4414_Movia_::
#
# DK::ServiceLink:514575__512774_::
# DK::ScheduledStopPoint:2132_Movia_::
# DK::ScheduledStopPoint:4415_Movia_::
#
# DK::ServiceLink:512774__512776_::
# DK::ScheduledStopPoint:2134_Movia_::
# DK::ScheduledStopPoint:2132_Movia_::
#
# DK::ServiceLink:512776__512779_::
# DK::ScheduledStopPoint:2137_Movia_::
# DK::ScheduledStopPoint:2134_Movia_::
#
# DK::ServiceLink:512779__512781_::
# DK::ScheduledStopPoint:2139_Movia_::
# DK::ScheduledStopPoint:2137_Movia_::
#
# DK::ServiceLink:512781__512782_::
# DK::ScheduledStopPoint:2140_Movia_::
# DK::ScheduledStopPoint:2139_Movia_::
#
# DK::ServiceLink:512782__511313_::
# DK::ScheduledStopPoint:285_Movia_::
# DK::ScheduledStopPoint:2140_Movia_::
#
# DK::ServiceLink:511313__512785_::
# DK::ScheduledStopPoint:2143_Movia_::
# DK::ScheduledStopPoint:285_Movia_::
#
# DK::ServiceLink:512785__512788_::
# DK::ScheduledStopPoint:2146_Movia_::
# DK::ScheduledStopPoint:2143_Movia_::
#
# DK::ServiceLink:512788__512790_::
# DK::ScheduledStopPoint:2148_Movia_::
# DK::ScheduledStopPoint:2146_Movia_::
#
# DK::ServiceLink:512790__512871_::
# DK::ScheduledStopPoint:2275_Movia_::
# DK::ScheduledStopPoint:2148_Movia_::
#
# DK::ServiceLink:512871__512670_::
# DK::ScheduledStopPoint:2008_Movia_::
# DK::ScheduledStopPoint:2275_Movia_::
#
# DK::ServiceLink:512670__512672_::
# DK::ScheduledStopPoint:2010_Movia_::
# DK::ScheduledStopPoint:2008_Movia_::
#
# DK::ServiceLink:512672__512791_::
# DK::ScheduledStopPoint:2149_Movia_::
# DK::ScheduledStopPoint:2010_Movia_::
#
# DK::ServiceLink:512791__512792_::
# DK::ScheduledStopPoint:2150_Movia_::
# DK::ScheduledStopPoint:2149_Movia_::
#
# DK::ServiceLink:512792__512793_::
# DK::ScheduledStopPoint:2151_Movia_::
# DK::ScheduledStopPoint:2150_Movia_::
#
# DK::ServiceLink:512793__512794_::
# DK::ScheduledStopPoint:2152_Movia_::
# DK::ScheduledStopPoint:2151_Movia_::
#
# DK::ServiceLink:512794__525506_::
# DK::ScheduledStopPoint:45740_Movia_::
# DK::ScheduledStopPoint:2152_Movia_::
#
# DK::ServiceLink:525506__516341_::
# DK::ScheduledStopPoint:6584_Movia_::
# DK::ScheduledStopPoint:45740_Movia_::
#
# DK::ServiceLink:519537__512796_::
# DK::ScheduledStopPoint:2157_Movia_::
# DK::ScheduledStopPoint:28329_Movia_::
#
# DK::ServiceLink:512796__525505_::
# DK::ScheduledStopPoint:45739_Movia_::
# DK::ScheduledStopPoint:2157_Movia_::
#
# DK::ServiceLink:525505__512798_::
# DK::ScheduledStopPoint:2159_Movia_::
# DK::ScheduledStopPoint:45739_Movia_::
#
# DK::ServiceLink:512798__716929_::
# DK::ScheduledStopPoint:52657_Movia_::
# DK::ScheduledStopPoint:2159_Movia_::
#
# DK::ServiceLink:716929__512800_::
# DK::ScheduledStopPoint:2161_Movia_::
# DK::ScheduledStopPoint:52657_Movia_::
#
# DK::ServiceLink:512800__512801_::
# DK::ScheduledStopPoint:2162_Movia_::
# DK::ScheduledStopPoint:2161_Movia_::
#
# DK::ServiceLink:512801__512679_::
# DK::ScheduledStopPoint:2022_Movia_::
# DK::ScheduledStopPoint:2162_Movia_::
#
# DK::ServiceLink:512679__512681_::
# DK::ScheduledStopPoint:2024_Movia_::
# DK::ScheduledStopPoint:2022_Movia_::
#
# DK::ServiceLink:512681__512764_::
# DK::ScheduledStopPoint:2121_Movia_::
# DK::ScheduledStopPoint:2024_Movia_::
#
# DK::ServiceLink:512764__511287_::
# DK::ScheduledStopPoint:258_Movia_::
# DK::ScheduledStopPoint:2121_Movia_::
#
# DK::ServiceLink:511287__512803_::
# DK::ScheduledStopPoint:2164_Movia_::
# DK::ScheduledStopPoint:258_Movia_::
#
# DK::ServiceLink:512803__511096_::
# DK::ScheduledStopPoint:23_Movia_::
# DK::ScheduledStopPoint:2164_Movia_::
#
# DK::ServiceLink:511096__511288_::
# DK::ScheduledStopPoint:260_Movia_::
# DK::ScheduledStopPoint:23_Movia_::
#
# DK::ServiceLink:511288__512808_::
# DK::ScheduledStopPoint:2169_Movia_::
# DK::ScheduledStopPoint:260_Movia_::
#
# DK::ServiceLink:512808__512809_::
# DK::ScheduledStopPoint:2170_Movia_::
# DK::ScheduledStopPoint:2169_Movia_::
#
# DK::ServiceLink:512809__512811_::
# DK::ScheduledStopPoint:2172_Movia_::
# DK::ScheduledStopPoint:2170_Movia_::
#
# DK::ServiceLink:512811__512814_::
# DK::ScheduledStopPoint:2175_Movia_::
# DK::ScheduledStopPoint:2172_Movia_::
#
# DK::ServiceLink:512814__512816_::
# DK::ScheduledStopPoint:2177_Movia_::
# DK::ScheduledStopPoint:2175_Movia_::
#
# DK::ServiceLink:512816__514597_::
# DK::ScheduledStopPoint:4451_Movia_::
# DK::ScheduledStopPoint:2177_Movia_::
#
# DK::ServiceLink:514597__514598_::
# DK::ScheduledStopPoint:4453_Movia_::
# DK::ScheduledStopPoint:4451_Movia_::
#
# DK::ServiceLink:514598__513874_::
# DK::ScheduledStopPoint:3560_Movia_::
# DK::ScheduledStopPoint:4453_Movia_::
#
# DK::ServiceLink:513874__513875_::
# DK::ScheduledStopPoint:3561_Movia_::
# DK::ScheduledStopPoint:3560_Movia_::
#
# DK::ServiceLink:513875__701448_B::
# DK::ScheduledStopPoint:52626_Movia_B::
# DK::ScheduledStopPoint:3561_Movia_::

# %%
# Get line name 

lines = dataObjects.find(".//netex:lines", namespace)
print("Lines", lines.tag)

for line in lines.findall(".//netex:Line", namespace):
    print(line.attrib['id'])
    print(line.find(".//netex:Name", namespace).text)
    print()
# Out:
# Lines {http://www.netex.org.uk/netex}lines
# DK::Line:7387::
# 350S
